# %% [markdown]
# # Introduction
#
# In the following notebook, I will be preprocessing our raw data and engineering new features to build a simple prediction model.

# %% [markdown]
# **Import Libraries**

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import plotly.express as px
import yaml
import os

# %% [markdown]
# **Set Notebook Preferences**

# %%
#Set pandas preferences
pd.set_option('display.max_columns', 100)

#Set visualization preferences
plt.style.use('ggplot')

fontdict= {'title_fontsize':16,
           'label_fontsize':12}

# %% [markdown]
# **Read-in Data**

# %%
#Change directory to my_config.yaml
os.chdir('C:/Users/kishe/Documents/Data Science/Projects/Python/In Progress/Car_Price_Prediction')

#Read yaml file
from box import Box

with open('my_config.yaml') as file:
    yaml_data= Box(yaml.safe_load(file))

#Read in raw data
raw_data= pd.read_csv(yaml_data.base.path.data)

# %% [markdown]
# ## View Visualizations from EDA

# %%
#Change directory to figures file to load images
os.chdir('C:/Users/kishe/Documents/Data Science/Projects/Python/In Progress/Car_Price_Prediction/Reports/Figures/')

#Read in visualizations

# %%
#Import library
from IPython.display import Image

# Load visualizations from local storage
Image(filename = "RawDataHeatmap.png", width = 600, height = 300)

# %%
Image(filename = "RawDataBoxplot.png", width = 600, height = 300)

# %%
Image(filename = "RawDataScatterplot.png", width = 600, height = 300)

# %%
Image(filename = "RawDataPriceDistribution.png", width = 600, height = 300)

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## Testing

# %% [markdown]
# ## Categorical Features

# %% [markdown]
# ## Numerical Features

# %% [markdown]
# # Feature Engineering
