# %% [markdown]
# ## Introduction
#
# In the following notebook, we will be doing a quick statistical analysis of our raw data (GeelyAutoCarPrices_Raw.csv)

# %% [markdown]
# **Import Libraries**

# %%
import pandas as pd
import numpy as np
import yaml
import os

# %% [markdown]
# **Set Notebook Preferences**

# %%
#Set pandas preferences
pd.set_option('display.max_columns', 100)

# %% [markdown]
# **Read-in Data**

# %%
#Change directory to my_config.yaml
os.chdir('C:/Users/kishe/Documents/Data Science/Projects/Python/In Progress/Car_Price_Prediction')

#Read yaml file
from box import Box

with open('my_config.yaml') as file:
    yaml_data= Box(yaml.safe_load(file))

#Read in raw data
auto_data = pd.read_csv(yaml_data.base.path.data)

# %% [markdown]
# ## Data Overview

# %% [markdown]
# **Preview Data**

# %%
print('Data shape:',auto_data.shape)
auto_data.head()
# Out:
# Data shape: (205, 26)
#    car_ID  symboling                          CarName fueltype aspiration  \
# 0      50          0                        jaguar xk      gas        std
# 1      74          0            buick century special      gas        std
# 2      75          1  buick regal sport coupe (turbo)      gas        std
# 3      48          0                        jaguar xj      gas        std
# 4      49          0                        jaguar xf      gas        std
#
#   doornumber  carbody drivewheel enginelocation  wheelbase  carlength  \
# 0        two    sedan        rwd          front      102.0      191.7
# 1       four    sedan        rwd          front      120.9      208.1
# 2        two  hardtop        rwd          front      112.0      199.2
# 3       four    sedan        rwd          front      113.0      199.6
# 4       four    sedan        rwd          front      113.0      199.6
#
#    carwidth  carheight  curbweight enginetype cylindernumber  enginesize  \
# 0      70.6       47.8        3950       ohcv         twelve         326
# 1      71.7       56.7        3900       ohcv          eight         308
# 2      72.0       55.4        3715       ohcv          eight         304
# 3      69.6       52.8        4066       dohc            six         258
# 4      69.6       52.8        4066       dohc            six         258
#
#   fuelsystem  boreratio  stroke  compressionratio  horsepower  peakrpm  \
# 0       mpfi       3.54    2.76              11.5         262     5000
# 1       mpfi       3.80    3.35               8.0         184     4500
# 2       mpfi       3.80    3.35               8.0         184     4500
# 3       mpfi       3.63    4.17               8.1         176     4750
# 4       mpfi       3.63    4.17               8.1         176     4750
#
#    citympg  highwaympg    price
# 0       13          17  36000.0
# 1       14          16  40960.0
# 2       14          16  45400.0
# 3       15          19  32250.0
# 4       15          19  35550.0

# %% [markdown]
# **About the Variables**

# %%
#View info
auto_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
#  16  enginesize        205 non-null    int64
#  17  fuelsystem        205 non-null    object
#  18  boreratio         205 non-null    float64
#  19  stroke            205 non-null    float64
#  20  compressionratio  205 non-null    float64
#  21  horsepower        205 non-null    int64
#  22  peakrpm           205 non-null    int64
#  23  citympg           205 non-null    int64
#  24  highwaympg        205 non-null    int64
#  25  price             205 non-null    float64
# dtypes: float64(8), int64(8), object(10)
# memory usage: 41.8+ KB

# %% [markdown]
# **Descriptive Statistics about the Data**

# %%
auto_data.describe().T
# Out:
#                   count          mean          std      min      25%  \
# car_ID            205.0    103.000000    59.322565     1.00    52.00
# symboling         205.0      0.834146     1.245307    -2.00     0.00
# wheelbase         205.0     98.756585     6.021776    86.60    94.50
# carlength         205.0    174.049268    12.337289   141.10   166.30
# carwidth          205.0     65.907805     2.145204    60.30    64.10
# carheight         205.0     53.724878     2.443522    47.80    52.00
# curbweight        205.0   2555.565854   520.680204  1488.00  2145.00
# enginesize        205.0    126.907317    41.642693    61.00    97.00
# boreratio         205.0      3.329756     0.270844     2.54     3.15
# stroke            205.0      3.255415     0.313597     2.07     3.11
# compressionratio  205.0     10.142537     3.972040     7.00     8.60
# horsepower        205.0    104.117073    39.544167    48.00    70.00
# peakrpm           205.0   5125.121951   476.985643  4150.00  4800.00
# citympg           205.0     25.219512     6.542142    13.00    19.00
# highwaympg        205.0     30.751220     6.886443    16.00    25.00
# price             205.0  13276.710571  7988.852332  5118.00  7788.00
#
#                        50%       75%       max
# car_ID              103.00    154.00    205.00
# symboling             1.00      2.00      3.00
# wheelbase            97.00    102.40    120.90
# carlength           173.20    183.10    208.10
# carwidth             65.50     66.90     72.30
# carheight            54.10     55.50     59.80
# curbweight         2414.00   2935.00   4066.00
# enginesize          120.00    141.00    326.00
# boreratio             3.31      3.58      3.94
# stroke                3.29      3.41      4.17
# compressionratio      9.00      9.40     23.00
# horsepower           95.00    116.00    288.00
# peakrpm            5200.00   5500.00   6600.00
# citympg              24.00     30.00     49.00
# highwaympg           30.00     34.00     54.00
# price             10295.00  16503.00  45400.00

# %% [markdown]
# **Missing Data**

# %%
auto_data.isna().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64
